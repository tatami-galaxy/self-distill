# %%
import json

# %%
with open('/home/ujan/self-distill/data/credit_assignment/advantages_opsd_final_answer_revkl_Qwen_Qwen3-1.7B_deepmath.jsonl', 'r', encoding='utf-8') as file:
    for line in file:
        data_item = json.loads(line)
        print(data_item.keys())
        raise
# Out:
# dict_keys(['problem_id', 'row_index', 'problem', 'gold_answer', 'level', 'subject', 'student_model', 'prompt_token_ids', 'completion_text', 'pred_answer', 'correct', 'num_completion_tokens', 'tokens', 'sampling', 'teacher_model', 'credit'])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 5
#       1 with open('/home/ujan/self-distill/data/credit_assignment/advantages_opsd_final_answer_revkl_Qwen_Qwen3-1.7B_deepmath.jsonl', 'r', encoding='utf-8') as file:
#       2     for line in file:
#       3         data_item = json.loads(line)
#       4         print(data_item.keys())
# ----> 5         raise
#
# RuntimeError: No active exception to reraise

# %%
with open('/home/ujan/self-distill/data/credit_assignment/errors_Qwen_Qwen3.6-27B_Qwen_Qwen3-1.7B_deepmath.jsonl', 'r', encoding='utf-8') as file:
    for line in file:
        data_item = json.loads(line)
        print(data_item.keys())
        print(data_item['first_error_step'])
        print(data_item['judge_raw'])
        raise
# Out:
# dict_keys(['problem_id', 'row_index', 'correct', 'student_model', 'judge_model', 'gold_answer', 'pred_answer', 'num_completion_tokens', 'segmentation', 'steps', 'first_error_step', 'first_error_tok_span', 'label', 'judge_error', 'judge_raw'])
# 45
# The user wants me to grade a student's step-by-step solution to find the limiting value of the p-norm of $f(x)=x$ on $[a, b]$ as $p \to \infty$.
# The correct answer is $\max(|a|, |b|)$.
# The student's solution concludes with $\max(a, b)$. This is incorrect if $a$ or $b$ are negative. For example, if $a=-2, b=1$, the correct limit is $\max(|-2|, |1|) = 2$, but the student's answer gives $\max(-2, 1) = 1$.
# Let's trace the student's steps to find the first error.
#
# Step 3: "Since f(x) = x is positive over [a, b], assuming that a and b are such that x is non-negative in the interval." - This is an assumption, but the student notes it.
# Step 4: Discusses sign.
# ...
